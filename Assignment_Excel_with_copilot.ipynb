# %% [markdown]
# # Excel With Copilot - Assignment
# **Questions & Answers - Text Format**
#
# **Note:** Since I do not have access to Copilot, all tasks were performed manually in Microsoft Excel.
#
# ---
#
# **Q1. Identify and summarize missing values in the dataset.**
#
# **Answer:**
# After checking the dataset, the following missing values were found:
# - Region: 12 missing values
# - Category: 8 missing values
# - Units Sold: 7 missing values
# - Unit Price: 9 missing values
#
# ---
#
# **Q2. Fill missing values in the Region and Category columns.**
#
# **Answer:**
# Missing values were filled manually as follows:
# - Missing **Region** values were filled using the most frequent region for the corresponding Country.
# - Missing **Category** values were filled using the most common category for that region.
#
# After filling, no missing values remain in Region and Category columns.
#
# ---
#
# **Q3. Fill missing numeric values in the Units Sold and Unit Price columns.**
#
# **Answer:**
# Missing numeric values were filled using the **median** of each column:
# - Missing values in **Units Sold** were replaced with the median of the Units Sold column.
# - Missing values in **Unit Price** were replaced with the median of the Unit Price column.
#
# ---
#
# **Q4. Create a new calculated column Total Revenue.**
#
# **Answer:**
# A new column named **Total Revenue** was created with the formula:
# **Total Revenue = Units Sold × Unit Price**
#
# ---
#
# **Q5. Find the total price of Order ID = 'ORD0123'.**
#
# **Answer:**
# For **Order ID = ORD0123**:
# - Units Sold = 46
# - Unit Price = 344.55
# **Total Revenue = ₹15,849.30**
#
# ---
#
# **Q6. Generate a summary chart of average profit by region.**
#
# **Answer:**
# First, a **Profit** column was created using the formula:
# **Profit = Total Revenue - (Units Sold × Unit Cost)**
#
# Then, a **Bar Chart** was created to show **Average Profit by Region**.
#
# ---
#
# **Q7. Create a pivot table summarizing total sales by category and region.**
#
# **Answer:**
# A PivotTable was created with:
# - **Category** in Rows
# - **Region** in Columns
# - **Sum of Total Revenue** in Values
#
# This PivotTable summarizes total sales by Category and Region.
#
# ---
#
# **Q8. Build a dashboard combining key KPIs and charts.**
#
# **Answer:**
# A dashboard was built on a new sheet containing:
# - Key Performance Indicators (Total Revenue, Total Units Sold, Average Profit)
# - Column Chart showing Sales by Region
# - Pie Chart showing Sales by Category
# - Line Chart showing Monthly Sales Trend
# - Slicers for Region and Category
#
# ---
#
# **Q9. Generate a summary report.**
#
# **Answer:**
# **Summary Report:**
# The dataset shows good overall sales performance. The West region generated the highest revenue. Electronics and Beverages are the top-performing categories. There is opportunity for growth in other regions and categories.
#
# **Recommendation:** Focus marketing and inventory efforts on high-performing regions (especially West) and categories (Electronics and Beverages).
#
# -
